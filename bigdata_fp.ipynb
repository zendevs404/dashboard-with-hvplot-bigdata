# %% [markdown]
# <a href="https://colab.research.google.com/github/zendevs404/dashboard-with-hvplot-bigdata/blob/master/bigdata_fp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Kelompok 1:**\
# Nanda Pratama 				          : 22.11.4623\
# Muhammad Rafli Rangga Pratama 	: 22.11.4668\
# Devananda Fikri Muhammad Rafi	  : 22.11.4669\
# Yuli Dwi Kurniawan			        : 22.11.4675

# %% [markdown]
# # (A) Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from pandas.plotting import scatter_matrix
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error
from scipy.stats import shapiro, kstest, probplot

import panel as pn
import hvplot.pandas

# %%
# !pip install panel hvplot
# Out:
# Requirement already satisfied: panel in /usr/local/lib/python3.10/dist-packages (1.3.8)
# Requirement already satisfied: hvplot in /usr/local/lib/python3.10/dist-packages (0.10.0)
# Requirement already satisfied: bokeh<3.4.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from panel) (3.3.4)
# Requirement already satisfied: param<3.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from panel) (2.1.1)
# Requirement already satisfied: pyviz-comms>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from panel) (3.0.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /usr/local/lib/python3.10/dist-packages (from panel) (2024.6.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from panel) (3.6)
# Requirement already satisfied: markdown-it-py in /usr/local/lib/python3.10/dist-packages (from panel) (3.0.0)
# Requirement already satisfied: linkify-it-py in /usr/local/lib/python3.10/dist-packages (from panel) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.10/dist-packages (from panel) (0.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from panel) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in /usr/local/lib/python3.10/dist-packages (from panel) (4.66.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from panel) (6.1.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from panel) (4.12.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from panel) (2.0.3)
# Requirement already satisfied: colorcet>=2 in /usr/local/lib/python3.10/dist-packages (from hvplot) (3.1.0)
# Requirement already satisfied: holoviews>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from hvplot) (1.17.1)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from hvplot) (1.25.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from hvplot) (24.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.4.0,>=3.2.0->panel) (3.1.4)
# Requirement already satisfied: contourpy>=1 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.4.0,>=3.2.0->panel) (1.2.1)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.4.0,>=3.2.0->panel) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.4.0,>=3.2.0->panel) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.10/dist-packages (from bokeh<3.4.0,>=3.2.0->panel) (6.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->panel) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->panel) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->panel) (2024.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from bleach->panel) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.10/dist-packages (from linkify-it-py->panel) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py->panel) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->panel) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->panel) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->panel) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->panel) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh<3.4.0,>=3.2.0->panel) (2.1.5)

# %%
pn.extension('tabulator')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='7c617e35-c8a0-46b7-b612-089a96dd71e5'>
#   <div id="d18c1c6c-06c5-4a4f-ba52-8eccbe251631" data-root-id="7c617e35-c8a0-46b7-b612-089a96dd71e5" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"35ec8c50-bc8a-48f5-96f9-01135396ff4b":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"7c617e35-c8a0-46b7-b612-089a96dd71e5"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"5b84e409-951d-4859-b012-35c546f91c17","attributes":{"plot_id":"7c617e35-c8a0-46b7-b612-089a96dd71e5","comm_id":"5a9649fc101144219764c7d23e4a864b","client_comm_id":"a2080217df87485384000a29bdead5b0"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":" ...
#   var render_items = [{"docid":"35ec8c50-bc8a-48f5-96f9-01135396ff4b","roots":{"7c617e35-c8a0-46b7-b612-089a96dd71e5":"d18c1c6c-06c5-4a4f-ba52-8eccbe251631"},"root_ids":["7c617e35-c8a0-46b7-b612-089a96dd71e5"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined) && ( root['Tabulator'] !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# # (B) Dataset

# %% [markdown]
# ## 1. Load Dataset

# %%
df = pd.read_csv("/content/rumah123_yogya_unfiltered.csv")
print(df.head)
# Out:
# <bound method NDFrame.head of                price                                           nav-link  \
# 0     Rp 1,79 Miliar  https://www.rumah123.com/properti/sleman/hos17...
# 1        Rp 170 Juta  https://www.rumah123.com/properti/sleman/hos17...
# 2        Rp 695 Juta  https://www.rumah123.com/properti/sleman/hos17...
# 3        Rp 560 Juta  https://www.rumah123.com/properti/sleman/hos17...
# 4        Rp 200 Juta  https://www.rumah123.com/properti/sleman/hos17...
# ...              ...                                                ...
# 2015     Rp 500 Juta  https://www.rumah123.com/properti/sleman/hos17...
# 2016     Rp 750 Juta  https://www.rumah123.com/properti/sleman/hos17...
# 2017     Rp 756 Juta  https://www.rumah123.com/properti/sleman/hos17...
# 2018  Rp 1,78 Miliar  https://www.rumah123.com/properti/sleman/hos16...
# 2019   Rp 2,3 Miliar  https://www.rumah123.com/properti/yogyakarta/h...
#
#                                             description    listing-location  \
# 0     Rumah 2 Lantai Baru  di jalan Palagan Sleman Y...     Ngaglik, Sleman
# 1                     RUMAH BARU DEKAT AL AZHAR DAN UGM      Jombor, Sleman
# 2     RUMAH ASRI DAN SEJUK DI BERBAH SLEMAN DEKAT PA...      Berbah, Sleman
# 3     Rumah Murah 5 Menit Dari Candi Prambanan Tersi...   Prambanan, Sleman
# 4             Rumah Murah Cicilan 1jt Di Moyudan Sleman     Moyudan, Sleman
# ...                                                 ...                 ...
# 2015  Rumah Baru, 500 Juta, Bisa Kpr Di Kalasan, Sleman     Kalasan, Sleman
# 2016           RUMAH MINIMALIS AREA JL KABUPATEN SLEMAN     Gamping, Sleman
# 2017  RUMAH SKANDINAVIAN DI JL GITOGATI NGAGLIK (5 M...     Ngaglik, Sleman
# 2018  Rumah Mewah Dekat Kampus Ugm di Maguwoharjo Da...       Depok, Sleman
# 2019  Jual Rumah Siap Huni di Perumahan Dayu Permai,...  Sleman, Yogyakarta
#
#       bed  bath  carport surface_area building_area
# 0     3.0   3.0      2.0       120 m²        110 m²
# 1     3.0   2.0      1.0       102 m²        126 m²
# 2     2.0   2.0      1.0       100 m²        100 m²
# 3     3.0   1.0      1.0       109 m²         67 m²
# 4     2.0   1.0      1.0        60 m²         30 m²
# ...   ...   ...      ...          ...           ...
# 2015  3.0   2.0      2.0       104 m²         80 m²
# 2016  2.0   1.0      1.0        89 m²         60 m²
# 2017  2.0   1.0      2.0       140 m²         60 m²
# 2018  4.0   3.0      2.0       118 m²        160 m²
# 2019  4.0   3.0      1.0       200 m²        180 m²
#
# [2020 rows x 9 columns]>

# %% [markdown]
# ## 2. View Dataset Information

# %% [markdown]
# ### - View dataset column and row size

# %%
df.shape
# Out:
# (2020, 9)

# %% [markdown]
# ### - View dataset description and info

# %%
df.describe()
# Out:
#                bed         bath      carport
# count  2001.000000  1999.000000  1713.000000
# mean      3.969015     2.941971     1.559253
# std       3.671654     3.517671     1.283030
# min       1.000000     1.000000     1.000000
# 25%       2.000000     1.000000     1.000000
# 50%       3.000000     2.000000     1.000000
# 75%       4.000000     3.000000     2.000000
# max      49.000000    49.000000    15.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2020 entries, 0 to 2019
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             2020 non-null   object
#  1   nav-link          2020 non-null   object
#  2   description       2020 non-null   object
#  3   listing-location  2020 non-null   object
#  4   bed               2001 non-null   float64
#  5   bath              1999 non-null   float64
#  6   carport           1713 non-null   float64
#  7   surface_area      2019 non-null   object
#  8   building_area     2019 non-null   object
# dtypes: float64(3), object(6)
# memory usage: 142.2+ KB

# %% [markdown]
# ## 3. Check for Null Data

# %%
df.isna().sum()
# Out:
# price                 0
# nav-link              0
# description           0
# listing-location      0
# bed                  19
# bath                 21
# carport             307
# surface_area          1
# building_area         1
# dtype: int64

# %% [markdown]
# # (C) EDA Process

# %% [markdown]
# ## 1. Check for Duplicate Data

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 2. Drop Unrelated Columns

# %%
df.drop(columns=['nav-link', 'description'], inplace=True)

# %% [markdown]
# ## 3. Convert Non-Numeric Variables to Numeric

# %% [markdown]
# ### - Price

# %%
# Price
def convert_price(price):
    price = price.replace("Rp ", "").replace(",", ".")
    if "Miliar" in price:
        return float(price.replace(" Miliar", "")) * 1_000_000_000
    elif "Juta" in price:
        return float(price.replace(" Juta", "")) * 1_000_000
    return None

df['price'] = df['price'].apply(convert_price)

# %% [markdown]
# ### - Surface Area and Building Area

# %%
# Remove units on surface_area building_area
def convert_area(area):
    if isinstance(area, str):
        area = area.replace(" m²", "").replace(",", "")
        return float(area)
    return area

df['surface_area'] = df['surface_area'].apply(convert_area)
df['building_area'] = df['building_area'].apply(convert_area)

# %% [markdown]
# ### - Listing Location Using Encode

# %%
le_listing_location = LabelEncoder()
df['listing-location'] = le_listing_location.fit_transform(df['listing-location'].astype(str))

# %% [markdown]
# ## 4. Fill the Null Columns Using Mode and Average

# %%
# Mengisi nilai kosong di kolom 'bed', 'bath', dan 'carport' dengan modus
df['bed'].fillna(df['bed'].mode()[0], inplace=True)
df['bath'].fillna(df['bath'].mode()[0], inplace=True)
df['carport'].fillna(df['carport'].mode()[0], inplace=True)

# Mengisi nilai kosong di kolom 'surface_area' dan 'building_area' dengan rata-rata
df['surface_area'].fillna(df['surface_area'].mean(), inplace=True)
df['building_area'].fillna(df['building_area'].mean(), inplace=True)

# %% [markdown]
# ## 5. Checking Dataset

# %%
df.isna().sum()
# Out:
# price               0
# listing-location    0
# bed                 0
# bath                0
# carport             0
# surface_area        0
# building_area       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2020 entries, 0 to 2019
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             2020 non-null   float64
#  1   listing-location  2020 non-null   int64
#  2   bed               2020 non-null   float64
#  3   bath              2020 non-null   float64
#  4   carport           2020 non-null   float64
#  5   surface_area      2020 non-null   float64
#  6   building_area     2020 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 110.6 KB

# %% [markdown]
# ## 6. Remove Outlier Variables

# %% [markdown]
# ### - Check if the dataset is normally distributed

# %%
# Uji Normalitas
columns_to_test = ['price', 'surface_area']

for column in columns_to_test:
    stat, p = shapiro(df[column].dropna())
    print(f'Shapiro-Wilk Test for {column}: Statistics={stat}, p-value={p}')
    stat, p = kstest(df[column].dropna(), 'norm')
    print(f'Kolmogorov-Smirnov Test for {column}: Statistics={stat}, p-value={p}')

    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    sns.histplot(df[column], kde=True)
    plt.title(f'Histogram of {column}')

    plt.subplot(1, 2, 2)
    probplot(df[column], dist="norm", plot=plt)
    plt.title(f'Q-Q Plot of {column}')

    plt.tight_layout()
    plt.show()
# Out:
# Shapiro-Wilk Test for price: Statistics=0.4700184464454651, p-value=0.0
# Kolmogorov-Smirnov Test for price: Statistics=1.0, p-value=0.0
# Shapiro-Wilk Test for surface_area: Statistics=0.3861241340637207, p-value=0.0
# Kolmogorov-Smirnov Test for surface_area: Statistics=0.9999683287581669, p-value=0.0

# %%
# Uji Normalitas
columns_to_test = ['bed']

for column in columns_to_test:
    stat, p = shapiro(df[column].dropna())
    print(f'Shapiro-Wilk Test for {column}: Statistics={stat}, p-value={p}')
    stat, p = kstest(df[column].dropna(), 'norm')
    print(f'Kolmogorov-Smirnov Test for {column}: Statistics={stat}, p-value={p}')

    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    sns.histplot(df[column], kde=True)
    plt.title(f'Histogram of {column}')

    plt.subplot(1, 2, 2)
    probplot(df[column], dist="norm", plot=plt)
    plt.title(f'Q-Q Plot of {column}')

    plt.tight_layout()
    plt.show()
# Out:
# Shapiro-Wilk Test for bed: Statistics=0.4725208282470703, p-value=0.0
# Kolmogorov-Smirnov Test for bed: Statistics=0.9658637294379594, p-value=0.0

# %%
# Uji Normalitas
columns_to_test = ['bath', 'carport']

for column in columns_to_test:
    stat, p = shapiro(df[column].dropna())
    print(f'Shapiro-Wilk Test for {column}: Statistics={stat}, p-value={p}')
    stat, p = kstest(df[column].dropna(), 'norm')
    print(f'Kolmogorov-Smirnov Test for {column}: Statistics={stat}, p-value={p}')

    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    sns.histplot(df[column], kde=True)
    plt.title(f'Histogram of {column}')

    plt.subplot(1, 2, 2)
    probplot(df[column], dist="norm", plot=plt)
    plt.title(f'Q-Q Plot of {column}')

    plt.tight_layout()
    plt.show()
# Out:
# Shapiro-Wilk Test for bath: Statistics=0.4584779739379883, p-value=0.0
# Kolmogorov-Smirnov Test for bath: Statistics=0.8413447460685429, p-value=0.0
# Shapiro-Wilk Test for carport: Statistics=0.424538791179657, p-value=0.0
# Kolmogorov-Smirnov Test for carport: Statistics=0.8413447460685429, p-value=0.0

# %% [markdown]
# ### - Remove outliers from 5 specific columns in a dataset

# %%
# Mendeteksi dan menghapus outlier menggunakan IQR
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# Menghapus outlier dari kolom yang relevan
columns_to_clean = ['price', 'surface_area', 'building_area', 'bed', 'bath']
for column in columns_to_clean:
    df = remove_outliers(df, column)

# Menampilkan box plot untuk memvisualisasikan outlier
plt.figure(figsize=(18, 10))

for i, column in enumerate(columns_to_clean, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(y=df[column])
    plt.title(f'Box Plot {column}')

plt.tight_layout()
plt.show()

# %%
df.shape

print(df.head)
# Out:
# <bound method NDFrame.head of              price  listing-location  bed  bath  carport  surface_area  \
# 0     1.790000e+09                39  3.0   3.0      2.0         120.0
# 1     1.700000e+08                22  3.0   2.0      1.0         102.0
# 2     6.950000e+08                 4  2.0   2.0      1.0         100.0
# 3     5.600000e+08                50  3.0   1.0      1.0         109.0
# 4     2.000000e+08                37  2.0   1.0      1.0          60.0
# ...            ...               ...  ...   ...      ...           ...
# 2015  5.000000e+08                23  3.0   2.0      2.0         104.0
# 2016  7.500000e+08                13  2.0   1.0      1.0          89.0
# 2017  7.560000e+08                39  2.0   1.0      2.0         140.0
# 2018  1.780000e+09                12  4.0   3.0      2.0         118.0
# 2019  2.300000e+09                61  4.0   3.0      1.0         200.0
#
#       building_area
# 0             110.0
# 1             126.0
# 2             100.0
# 3              67.0
# 4              30.0
# ...             ...
# 2015           80.0
# 2016           60.0
# 2017           60.0
# 2018          160.0
# 2019          180.0
#
# [1464 rows x 7 columns]>

# %%
df.to_csv('RumahYogya.csv', index=False)

# %% [markdown]
# # (D) Correlation

# %%
# Melanjutkan analisis dan model prediksi
corr = df.corr()
print(df.corr())

plt.figure(figsize=(10, 5))
sns.heatmap(df.corr(), annot=True, fmt='.2f')
plt.title('Plot correlation matriks dengan sns.heatmap')
plt.tight_layout()
plt.show()
# Out:
#                      price  listing-location       bed      bath   carport  \
# price             1.000000          0.024191  0.598917  0.734165  0.227780
# listing-location  0.024191          1.000000 -0.035835 -0.068215  0.025527
# bed               0.598917         -0.035835  1.000000  0.733045  0.193702
# bath              0.734165         -0.068215  0.733045  1.000000  0.210131
# carport           0.227780          0.025527  0.193702  0.210131  1.000000
# surface_area      0.689223          0.088068  0.533980  0.527917  0.202484
# building_area     0.752510         -0.023044  0.691811  0.717742  0.131690
#
#                   surface_area  building_area
# price                 0.689223       0.752510
# listing-location      0.088068      -0.023044
# bed                   0.533980       0.691811
# bath                  0.527917       0.717742
# carport               0.202484       0.131690
# surface_area          1.000000       0.604908
# building_area         0.604908       1.000000

# %%
#Korelasi keseluruhan antar kolom bernilai
plt.clf()

_, ax = plt.subplots(1, 1, figsize=(25,25))
scatter_matrix(df, ax=ax)
plt.show()
# Out:
# <ipython-input-33-3eac8fc43200>:5: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   scatter_matrix(df, ax=ax)

# %%
# Menampilkan scatter plot untuk variabel dengan korelasi tinggi terhadap harga
high_corr = corr['price'][corr['price'].abs() > 0.5].index.drop('price')

for col in high_corr:
    plt.figure(figsize=(10, 5))
    sns.scatterplot(x=col, y='price', data=df)
    plt.title(f'Scatter Plot antara {col} dan Price')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # (E) Linear Regression

# %% [markdown]
# ## 1. Using 4 Variable

# %%
# Model 1: Using 'surface_area', 'building_area', 'bed', 'bath'
X1 = df[['surface_area', 'building_area', 'bed', 'bath']]
y1 = df['price']

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.2, random_state=100)

# %%
print(X1_train.shape)
print(X1_test.shape)
# Out:
# (1171, 4)
# (293, 4)

# %%
regr1 = LinearRegression()
regr1.fit(X1_train, y1_train)
# Out:
# LinearRegression()

# %%
print('Model 1 - intercept:', regr1.intercept_)
print('Model 1 - Coef:', regr1.coef_)
# Out:
# Model 1 - intercept: -537133049.4532876
# Model 1 - Coef: [ 6.31983048e+06  5.72623201e+06 -1.09399280e+08  3.55867226e+08]

# %%
pred1 = regr1.predict(X1_test)
rmse1 = np.sqrt(mean_squared_error(y1_test, pred1))
r2_1 = r2_score(y1_test, pred1)
mape1 = mean_absolute_percentage_error(y1_test, pred1) * 100  # Convert MAPE to percentage
print('Model 1 - RMSE:', rmse1)
print('Model 1 - R2 Score:', r2_1)
print('Model 1 - MAPE:', mape1, '%')
# Out:
# Model 1 - RMSE: 414129327.7353847
# Model 1 - R2 Score: 0.6610017895644853
# Model 1 - MAPE: 31.091648567113218 %

# %% [markdown]
# ## 2. Using 3 Variable

# %%
# Model 2: Using 'surface_area', 'building_area', 'bath'
X2 = df[['surface_area', 'building_area', 'bath']]
y2 = df['price']

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=100)

# %%
print(X2_train.shape)
print(X2_test.shape)
# Out:
# (1171, 3)
# (293, 3)

# %%
regr2 = LinearRegression()
regr2.fit(X2_train, y2_train)
# Out:
# LinearRegression()

# %%
print('Model 2 - intercept:', regr2.intercept_)
print('Model 2 - Coef:', regr2.coef_)
# Out:
# Model 2 - intercept: -683664249.0169601
# Model 2 - Coef: [6.08074713e+06 5.21660951e+06 3.09558951e+08]

# %%
pred2 = regr2.predict(X2_test)
rmse2 = np.sqrt(mean_squared_error(y2_test, pred2))
r2_2 = r2_score(y2_test, pred2)
mape2 = mean_absolute_percentage_error(y2_test, pred2) * 100  # Convert MAPE to percentage
print('Model 2 - RMSE:', rmse2)
print('Model 2 - R2 Score:', r2_2)
print('Model 2 - MAPE:', mape2, '%')
# Out:
# Model 2 - RMSE: 414388481.36038023
# Model 2 - R2 Score: 0.6605773805820898
# Model 2 - MAPE: 30.71840475647122 %

# %% [markdown]
# ## 3. Using 2 Variable

# %%
# Model 3: Using 'building_area', 'bath'
X3 = df[['building_area', 'bath']]
y3 = df['price']

# %%
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, test_size=0.2, random_state=100)

# %%
print(X3_train.shape)
print(X3_test.shape)
# Out:
# (1171, 2)
# (293, 2)

# %%
regr3 = LinearRegression()
regr3.fit(X3_train, y3_train)
# Out:
# LinearRegression()

# %%
print('Model 3 - intercept:', regr3.intercept_)
print('Model 3 - Coef:', regr3.coef_)
# Out:
# Model 3 - intercept: -304553714.3478503
# Model 3 - Coef: [7.48231769e+06 3.75328867e+08]

# %%
pred3 = regr3.predict(X3_test)
rmse3 = np.sqrt(mean_squared_error(y3_test, pred3))
r2_3 = r2_score(y3_test, pred3)
mape3 = mean_absolute_percentage_error(y3_test, pred3) * 100  # Convert MAPE to percentage
print('Model 3 - RMSE:', rmse3)
print('Model 3 - R2 Score:', r2_3)
print('Model 3 - MAPE:', mape3, '%')
# Out:
# Model 3 - RMSE: 456916067.5779953
# Model 3 - R2 Score: 0.5873343769642885
# Model 3 - MAPE: 33.38056263306514 %

# %% [markdown]
# ## 4. Testing Using 10 Data

# %%
# Contoh actual dan prediksi untuk 10 data
sample_data = df.sample(10, random_state=42)
sample_X1 = sample_data[['surface_area', 'building_area', 'bed', 'bath']]  # Untuk Model 1
sample_X2 = sample_data[['surface_area', 'building_area', 'bath']]         # Untuk Model 2
sample_X3 = sample_data[['building_area', 'bath']]                         # Untuk Model 3

sample_actual = sample_data['price'].values
sample_pred1 = regr1.predict(sample_X1)
sample_pred2 = regr2.predict(sample_X2)
sample_pred3 = regr3.predict(sample_X3)

print("\nContoh Actual dan Prediksi Harga untuk 10 Data:")
for i in range(10):
    print(f"Data ke-{i+1}:")
    print(f"Actual Price: {sample_actual[i]}")
    print(f"Prediksi Model 1: {sample_pred1[i]}")
    print(f"Prediksi Model 2: {sample_pred2[i]}")
    print(f"Prediksi Model 3: {sample_pred3[i]}\n")
# Out:
# Contoh Actual dan Prediksi Harga untuk 10 Data:
# Data ke-1:
# Actual Price: 407000000.0
# Prediksi Model 1: 363202495.47794473
# Prediksi Model 2: 347101900.4925449
# Prediksi Model 3: 407479448.4979923
#
# Data ke-2:
# Actual Price: 2600000000.0
# Prediksi Model 1: 2128830162.6332345
# Prediksi Model 2: 2148280480.63845
# Prediksi Model 3: 2243073246.8803964
#
# Data ke-3:
# Actual Price: 898000000.0
# Prediksi Model 1: 787393386.474206
# Prediksi Model 2: 821800512.8420148
# Prediksi Model 3: 932454669.2116897
#
# Data ke-4:
# Actual Price: 615000000.0
# Prediksi Model 1: 1290358188.2024047
# Prediksi Model 2: 1319538709.6464908
# Prediksi Model 3: 1043476451.7472856
#
# Data ke-5:
# Actual Price: 550000000.0
# Prediksi Model 1: 394801647.8930465
# Prediksi Model 2: 377505636.1610937
# Prediksi Model 3: 407479448.4979923
#
# Data ke-6:
# Actual Price: 475000000.0
# Prediksi Model 1: 455031960.3563268
# Prediksi Model 2: 433992419.38971305
# Prediksi Model 3: 444891036.9244213
#
# Data ke-7:
# Actual Price: 235000000.0
# Prediksi Model 1: 233070201.95226645
# Prediksi Model 2: 226287527.87636542
# Prediksi Model 3: 295244683.2187052
#
# Data ke-8:
# Actual Price: 645000000.0
# Prediksi Model 1: 421854491.7843988
# Prediksi Model 2: 504400755.91098285
# Prediksi Model 3: 519714213.77727926
#
# Data ke-9:
# Actual Price: 1100000000.0
# Prediksi Model 1: 1716511241.1046662
# Prediksi Model 2: 1690864620.7228942
# Prediksi Model 3: 1568451672.4609828
#
# Data ke-10:
# Actual Price: 2500000000.0
# Prediksi Model 1: 2015457059.6880422
# Prediksi Model 2: 2036266403.148427
# Prediksi Model 3: 2317896423.733255

# %%
# Dashboard Components
header = pn.pane.Markdown("# Real Estate Price Dashboard")

data_table = pn.widgets.Tabulator(df, height=300, width=800)

price_hist = df['price'].hvplot.hist(title='Price Distribution', bins=50, color='green')
surface_hist = df['surface_area'].hvplot.hist(title='Surface Area Distribution', bins=50, color='blue')
building_hist = df['building_area'].hvplot.hist(title='Building Area Distribution', bins=50, color='red')

correlation_heatmap = df.corr().hvplot.heatmap(title='Correlation Heatmap', cmap='viridis', annot=True)

scatter_matrix_plot = pn.panel(scatter_matrix(df, alpha=0.2, figsize=(25, 25), diagonal='kde'))

model1_results = pn.pane.Markdown(f"""
## Linear Regression Model 1 Results
- RMSE: {rmse1}
- R² Score: {r2_1}
- MAPE: {mape1}%
""")

model2_results = pn.pane.Markdown(f"""
## Linear Regression Model 2 Results
- RMSE: {rmse2}
- R² Score: {r2_2}
- MAPE: {mape2}%
""")

model3_results = pn.pane.Markdown(f"""
## Linear Regression Model 3 Results
- RMSE: {rmse3}
- R² Score: {r2_3}
- MAPE: {mape3}%
""")

sample_predictions = pn.pane.Markdown("## Sample Actual and Predicted Prices for 10 Data Points")
sample_table = pd.DataFrame({
    "Actual Price": sample_actual,
    "Predicted Price Model 1": sample_pred1,
    "Predicted Price Model 2": sample_pred2,
    "Predicted Price Model 3": sample_pred3
})

# Layout
dashboard = pn.Column(
    header,
    pn.Row(data_table),
    pn.Row(price_hist, surface_hist, building_hist),
    correlation_heatmap,
    scatter_matrix_plot,
    model1_results,
    model2_results,
    model3_results,
    sample_predictions,
    sample_table
)

dashboard.servable()
# Out:
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# WARNING:param.main: annot option not found for heatmap plot with bokeh; similar options include: []
# WARNING:param.main:annot option not found for heatmap plot with bokeh; similar options include: []
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# /usr/local/lib/python3.10/dist-packages/holoviews/core/util.py:1585: PanelDeprecationWarning: 'param_value_if_widget' is deprecated and will be removed in version 1.4, use 'transform_reference' instead.
#   value = param_value_if_widget(value)
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# Column
#     [0] Markdown(str)
#     [1] Row
#         [0] Tabulator(height=300, pagination='local', sizing_mode='fixed', value=             p..., width=800)
#     [2] Row
#         [0] HoloViews(Histogram, height=300, sizing_mode='fixed', width=700)
#         [1] HoloViews(Histogram, height=300, sizing_mode='fixed', width=700)
#         [2] HoloViews(Histogram, height=300, sizing_mode='fixed', width=700)
#     [3] HoloViews(HeatMap, height=300, sizing_mode='fixed', width=700)
#     [4] Str(ndarray)
#     [5] Markdown(str)
#     [6] Markdown(str)
#     [7] Markdown(str)
#     [8] Markdown(str)
#     [9] DataFrame(DataFrame)
